# %% [markdown]
# ## Settings

# %%
import os
import glob
import pandas as pd
import numpy as np

curfolder = os.getcwd()
# where do we store our processed timeseries data
processedfolder = os.path.join(curfolder, '../01_TS_processing/TS_merged/')
print(processedfolder)
processedfiles = glob.glob(processedfolder + '*.csv')
# get rid of all files that have 'anno' in their name
processedfiles = [x for x in processedfiles if 'anno' not in x]
print(processedfiles)


annofolder_auto = os.path.join(curfolder, '../02_0_TS_movementAnnotation/MT_annotated/')
annofolder_manu = os.path.join(curfolder, '../02_0_TS_movementAnnotation/ManualAnno/R1/')
annofiles_auto = glob.glob(annofolder_auto + '*ELAN_tiers.csv')
print(annofiles_auto)
annofiles_manu = glob.glob(annofolder_manu + '*ELAN_tiers.eaf')
print(annofiles_manu)

mergedfiles = glob.glob(processedfolder + '/merged*.csv')
mergedfiles = [x for x in mergedfiles if 'anno' not in x]

cleanedfolder = os.path.join(curfolder + '/TS_forSampling/')
samplingfiles = glob.glob(cleanedfolder + '*.csv')
print(samplingfiles)
# Out:
# e:\FLESH_ContinuousBodilyEffort\02_1_TS_movementClassification\../01_TS_processing/TS_merged/
# ['e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_10_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_18_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_2_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_8_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_9_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_2_111_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_2_112_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_0_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_3_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_4_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_5_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_6_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_7_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_11_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_12_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_13_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_14_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_15_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_16_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_17_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_19_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_20_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_21_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_22_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_23_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_24_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_25_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_26_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_27_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_28_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_29_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_30_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../01_TS_processing/TS_merged\\merged_0_1_31_p1.csv', 'e:\\FLESH_Co ...
# ['e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_0_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_10_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_11_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_12_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_13_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_14_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_15_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_16_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_17_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_18_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_19_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_1_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_20_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_21_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_22_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_23_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_24_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_25_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_26_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_27_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_28_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_29_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_2_p0_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_30_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_31_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_32_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_33_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_35_p1_ELAN_tiers.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/MT_annotated\\0_1_36_p0_ELAN_tiers.csv',  ...
# ['e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_11_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_12_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_13_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_14_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_15_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_16_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_17_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_20_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_21_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_22_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_23_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_24_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_25_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_26_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_29_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_30_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_31_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_32_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_33_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_34_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_35_p1_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_38_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_39_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_40_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_41_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_42_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_43_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno/R1\\0_1_44_p0_ELAN_tiers.eaf', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification\\../02_0_TS_movementAnnotation/ManualAnno ...
# ['e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_2_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_8_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_2_111_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_2_112_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_3_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_4_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_5_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_6_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_7_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_11_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_12_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_13_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_14_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_15_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_16_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_17_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_20_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_21_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_22_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_23_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_24_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_25_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_26_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_29_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_30_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_31_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_32_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_33_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_35_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_38_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_39_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_40_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_41_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dataset_0_1_42_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\02_1_TS_movementClassification/TS_forSampling\\sampling_dat ...

# %% [markdown]
# ## Create non-overlapping chunks from TS

# %%
import pandas as pd
import numpy as np

chunked_folder = os.path.join(curfolder + '/TS_forClassifying/')

# Function to transform dictionary into DataFrame
def dict_to_df(data):
    # Flatten the dictionary into a format with keys like 'feature_mean', 'feature_std', etc.
    flat_data = {}
    for feature, stats in data.items():
        for stat, value in stats.items():
            flat_data[f'{feature}_{stat}'] = value
    # Convert the flat dictionary to a DataFrame with a single row
    df = pd.DataFrame(flat_data, index=[0])
    return df

# Function to summarize every 50 rows in the DataFrame, with start and end time
def summarize_consecutive_rows(df, num_cols, summary_interval=50):
    summaries = []
    # create empty df to store all the rows
    summary_df = pd.DataFrame()

    counter = 1
    for start_idx in range(0, len(df), summary_interval):
        # Select a slice of 50 rows (or fewer for the last chunk)
        selected = df.iloc[start_idx:start_idx + summary_interval]
        summary_stats = {}

        # Calculate statistics for each numerical column
        for col in num_cols:
            stats = selected[col].describe().to_dict()
            summary_stats[col] = stats

        # Convert to DataFrame row format
        summary_row = dict_to_df(summary_stats)
        #summaries.append(summary_row)

        # Add start and end time for the chunk
        summary_row['start_time'] = selected['time'].iloc[0]
        summary_row['end_time'] = selected['time'].iloc[-1]

        # Add chunk number
        summary_row['eventid'] = f"{trialid}_chunk_{counter}"

        # get rid of all columns that contain count in name
        summary_row = summary_row.loc[:, ~summary_row.columns.str.contains('count|%', regex=True)]

        # Append to the main DataFrame
        summary_df = pd.concat([summary_df, summary_row], ignore_index=True)

        counter += 1
        
    # Concatenate all summaries into a single DataFrame
    #return pd.concat(summaries, ignore_index=True)
    return summary_df

# Main DataFrame to store all summaries
dataset_features = pd.DataFrame()

#counter = 1
for file in samplingfiles:
    df = pd.read_csv(file)
    trialid = file.split('\\')[-1].split('.')[0]

    # Define numerical columns (excluding 'time' and 'change' if present)
    num_cols = [col for col in df.select_dtypes(include=np.number).columns if col != 'change' and col != 'time']

    # Summarize data in intervals of 50 rows
    summary_df = summarize_consecutive_rows(df, num_cols, summary_interval=50)

    # Add trial ID and event ID
    summary_df['trialid'] = trialid

    # delete all columns that contain NAs
    summary_df = summary_df.dropna(axis=1, how='all')

    # save it as a csv
    summary_df.to_csv(chunked_folder + trialid + '_chunked.csv', index=False)

# %%
summary_df
# Out:
#     COPc_mean  COPc_std  COPc_min  COPc_max  pelvis_tilt_moment_mean  \
# 0    0.000319  0.000045  0.000185  0.000374                 2.823243
# 1    0.000118  0.000066  0.000019  0.000223                 2.895204
# 2    0.000141  0.000078  0.000028  0.000334                -4.858278
# 3    0.000219  0.000074  0.000098  0.000338                -3.138335
# 4    0.000197  0.000114  0.000015  0.000395                 3.323793
# 5    0.000336  0.000152  0.000018  0.000489                -2.819211
# 6    0.000229  0.000113  0.000025  0.000380                -2.946643
# 7    0.000191  0.000069  0.000045  0.000303                -2.206657
# 8    0.000208  0.000108  0.000043  0.000388                -1.305907
# 9    0.000450  0.000041  0.000357  0.000505                -2.757097
# 10   0.000184  0.000060  0.000121  0.000337                 0.659918
# 11   0.000191  0.000076  0.000018  0.000329                 1.200455
# 12   0.000075  0.000036  0.000018  0.000151                -3.331761
# 13   0.000168  0.000069  0.000002  0.000284                -2.896758
# 14   0.000221  0.000109  0.000029  0.000368                 1.288840
# 15   0.000083  0.000025  0.000035  0.000128                 0.575975
# 16   0.000124  0.000048  0.000032  0.000204                -0.896385
# 17   0.000176  0.000080  0.000048  0.000350                -0.812104
# 18   0.000246  0.000115  0.000094  0.000411                 0.665545
# 19   0.000287  0.000079  0.000191  0.000412                 1.445306
# 20   0.000112  0.000063  0.000011  0.000228                -3.376601
# 21   0.000265  0.000162  0.000052  0.000531                -1.661038
# 22   0.000201  0.000048  0.000122  0.000310                13.134625
# 23   0.000188  0.000120  0.000064  0.000496                -2.217557
# 24   0.000367  0.000152  0.000178  0.000592                 0.607114
# 25   0.000105  0.000046  0.000014  0.000172                 3.787322
# 26   0.000122  0.000042  0.000060  0.000192                 1.626993
# 27   0.000221  0.000217  0.000070  0.001044                 1.878334
#
#     pelvis_tilt_moment_std  pelvis_tilt_moment_min  pelvis_tilt_moment_max  \
# 0                 2.493456               -2.755942                5.258982
# 1                 1.907259               -0.835363                5.222930
# 2                 1.926899               -7.020259               -1.161564
# 3                 2.971652               -6.967406                2.251214
# 4                 1.060030                0.726824                4.456312
# 5                 1.444560               -4.123448                0.376315
# 6                 0.391114               -3.810794               -2.594273
# 7                 0.562379               -2.772062               -1.074329
# 8                 0.579197               -2.577998               -0.754541
# 9                 0.528329               -3.281886               -1.435788
# 10                1.009670               -1.265206                1.950046
# 11                0.826715               -0.623250                2.007482
# 12                1.353566               -4.944590               -0.822338
# 13                1.573335               -4.926917               -0.054326
# 14                0.450856                0.133981                1.688193
# 15                0.370578                0.007580                1.261804
# 16                0.534544               -1.667919               -0.038831
# 17                0.789434               -1.680013                0.748830
# 18                0.775980               -1.078300                1.429109
# 19                2.380340               -1.345330                4.880652
# 20                5.349877              -10.935868                4.725921
# 21                8.150614              -11.012091               13.614107
# 22                4.247594                4.090621               17.535510
# 23                2.329317               -4.288690                3.327382
# 24                2.110876               -3.014682                3.692915
# 25                0.472760                2.711145                4.279506
# 26                0.481264                1.114530                2.604908
# 27                0.483102                1.160897                2.397586
#
#     pelvis_list_moment_mean  pelvis_list_moment_std  ...  \
# 0                 28.172777                0.926994  ...
# 1                 33.469046                1.286910  ...
# 2                 30.850581                1.331618  ...
# 3                 35.981722                3.784587  ...
# 4                 43.583405                0.624344  ...
# 5                 37.840889                2.647704  ...
# 6                 32.774572                0.648342  ...
# 7                 36.426470                0.856838  ...
# 8                 36.714083                0.319982  ...
# 9                 37.619769                0.715812  ...
# 10                33.277922                1.061558  ...
# 11                36.530694                2.145268  ...
# 12                38.673459                1.459717  ...
# 13                33.083685                0.870889  ...
# 14                36.294347                1.345012  ...
# 15                36.325016                0.984162  ...
# 16                37.064300                1.868617  ...
# 17                44.658890                1.822949  ...
# 18                39.846715                5.866743  ...
# 19                24.166816                2.496467  ...
# 20                 4.880460               15.850292  ...
# 21                13.091039               21.608549  ...
# 22                26.149722               23.154768  ...
# 23               -13.252208                9.366818  ...
# 24                14.296935                2.613234  ...
# 25                15.754592                1.545615  ...
# 26                20.732153                1.017830  ...
# 27                 7.640004                6.009420  ...
#
#     HeadRankleDistance_y_min  HeadRankleDistance_y_max  \
# 0                 -18.529530                -18.180545
# 1                 -18.212594                -18.013578
# 2                 -18.570472                -18.231503
# 3                 -18.885873                -18.574870
# 4                 -18.900031                -18.815315
# 5                 -19.051894                -18.814193
# 6                 -19.181893                -19.055471
# 7                 -19.667147                -19.189120
# 8                 -19.981477                -19.671114
# 9                 -20.023929                -19.854825
# 10                -19.848882                -19.794135
# 11                -19.811517                -19.460527
# 12                -19.454823                -19.262128
# 13                -19.256956                -19.068312
# 14                -19.604160                -19.129675
# 15                -19.806877                -19.620570
# 16                -19.794103                -19.330589
# 17                -19.314799                -18.698952
# 18                -19.135892                -18.638910
# 19                -19.716183                -19.161650
# 20                -20.218566                -19.735428
# 21                -20.481680                -20.177239
# 22                -21.029329                -20.499863
# 23                -21.965124                -21.057713
# 24                -22.102071                -21.981547
# 25                -22.111862                -22.017203
# 26                -22.005686                -21.597821
# 27                -21.583417                -21.385561
#
#     HeadRankleDistance_z_mean  HeadRankleDistance_z_std  \
# 0                  158.007727                  0.061283
# 1                  157.812545                  0.042836
# 2                  157.834298                  0.036901
# 3                  157.963666                  0.029165
# 4                  158.084456                  0.026155
# 5                  158.084474                  0.022027
# 6                  158.208765                  0.029211
# 7                  158.152917                  0.023752
# 8                  158.033902                  0.059628
# 9                  157.887326                  0.015209
# 10                 157.973228                  0.049702
# 11                 158.160536                  0.049730
# 12                 158.304422                  0.019749
# 13                 158.314993                  0.006554
# 14                 158.332448                  0.031050
# 15                 158.368324                  0.010385
# 16                 158.298927                  0.057462
# 17                 158.209926                  0.020659
# 18                 158.335297                  0.081733
# 19                 158.590724                  0.043869
# 20                 158.670930                  0.014971
# 21                 158.472415                  0.120128
# 22                 158.023761                  0.099437
# 23                 157.884820                  0.017435
# 24                 157.800003                  0.022114
# 25                 157.772216                  0.036808
# 26                 157.418998                  0.157280
# 27                 156.956056                  0.095170
#
#     HeadRankleDistance_z_min  HeadRankleDistance_z_max  start_time  end_time  \
# 0                 157.905098                158.110047         0.0      98.0
# 1                 157.770362                157.897750       100.0     198.0
# 2                 157.787253                157.909403       200.0     298.0
# 3                 157.912900                158.022213       300.0     398.0
# 4                 158.028390                158.112310       400.0     498.0
# 5                 158.055122                158.133469       500.0     598.0
# 6                 158.137395                158.238322       600.0     698.0
# 7                 158.125374                158.210485       700.0     798.0
# 8                 157.931980                158.124281       800.0     898.0
# 9                 157.869993                157.928321       900.0     998.0
# 10                157.905862                158.067416      1000.0    1098.0
# 11                158.071285                158.246116      1100.0    1198.0
# 12                158.249496                158.318620      1200.0    1298.0
# 13                158.299038                158.320982      1300.0    1398.0
# 14                158.296037                158.380646      1400.0    1498.0
# 15                158.355924                158.382086      1500.0    1598.0
# 16                158.194895                158.361531      1600.0    1698.0
# 17                158.182282                158.237792      1700.0    1798.0
# 18                158.238816                158.486533      1800.0    1898.0
# 19                158.497228                158.643193      1900.0    1998.0
# 20                158.640169                158.689333      2000.0    2098.0
# 21                158.237796                158.633006      2100.0    2198.0
# 22                157.907059                158.218302      2200.0    2298.0
# 23                157.851051                157.905633      2300.0    2398.0
# 24                157.778449                157.847357      2400.0    2498.0
# 25                157.681545                157.803416      2500.0    2598.0
# 26                157.150830                157.667544      2600.0    2698.0
# 27                156.861994                157.131230      2700.0    2774.0
#
#                                eventid                    trialid
# 0    sampling_dataset_0_1_2_p0_chunk_1  sampling_dataset_0_1_2_p0
# 1    sampling_dataset_0_1_2_p0_chunk_2  sampling_dataset_0_1_2_p0
# 2    sampling_dataset_0_1_2_p0_chunk_3  sampling_dataset_0_1_2_p0
# 3    sampling_dataset_0_1_2_p0_chunk_4  sampling_dataset_0_1_2_p0
# 4    sampling_dataset_0_1_2_p0_chunk_5  sampling_dataset_0_1_2_p0
# 5    sampling_dataset_0_1_2_p0_chunk_6  sampling_dataset_0_1_2_p0
# 6    sampling_dataset_0_1_2_p0_chunk_7  sampling_dataset_0_1_2_p0
# 7    sampling_dataset_0_1_2_p0_chunk_8  sampling_dataset_0_1_2_p0
# 8    sampling_dataset_0_1_2_p0_chunk_9  sampling_dataset_0_1_2_p0
# 9   sampling_dataset_0_1_2_p0_chunk_10  sampling_dataset_0_1_2_p0
# 10  sampling_dataset_0_1_2_p0_chunk_11  sampling_dataset_0_1_2_p0
# 11  sampling_dataset_0_1_2_p0_chunk_12  sampling_dataset_0_1_2_p0
# 12  sampling_dataset_0_1_2_p0_chunk_13  sampling_dataset_0_1_2_p0
# 13  sampling_dataset_0_1_2_p0_chunk_14  sampling_dataset_0_1_2_p0
# 14  sampling_dataset_0_1_2_p0_chunk_15  sampling_dataset_0_1_2_p0
# 15  sampling_dataset_0_1_2_p0_chunk_16  sampling_dataset_0_1_2_p0
# 16  sampling_dataset_0_1_2_p0_chunk_17  sampling_dataset_0_1_2_p0
# 17  sampling_dataset_0_1_2_p0_chunk_18  sampling_dataset_0_1_2_p0
# 18  sampling_dataset_0_1_2_p0_chunk_19  sampling_dataset_0_1_2_p0
# 19  sampling_dataset_0_1_2_p0_chunk_20  sampling_dataset_0_1_2_p0
# 20  sampling_dataset_0_1_2_p0_chunk_21  sampling_dataset_0_1_2_p0
# 21  sampling_dataset_0_1_2_p0_chunk_22  sampling_dataset_0_1_2_p0
# 22  sampling_dataset_0_1_2_p0_chunk_23  sampling_dataset_0_1_2_p0
# 23  sampling_dataset_0_1_2_p0_chunk_24  sampling_dataset_0_1_2_p0
# 24  sampling_dataset_0_1_2_p0_chunk_25  sampling_dataset_0_1_2_p0
# 25  sampling_dataset_0_1_2_p0_chunk_26  sampling_dataset_0_1_2_p0
# 26  sampling_dataset_0_1_2_p0_chunk_27  sampling_dataset_0_1_2_p0
# 27  sampling_dataset_0_1_2_p0_chunk_28  sampling_dataset_0_1_2_p0
#
# [28 rows x 1548 columns]

# %% [markdown]
# ## Create chunks with sliding window

# %%
import pandas as pd
import numpy as np
import os

chunked_folder = os.path.join(curfolder + '/TS_forClassifying_SW/')

# Function to transform dictionary into DataFrame
def dict_to_df(data):
    # Flatten the dictionary into a format with keys like 'feature_mean', 'feature_std', etc.
    flat_data = {}
    for feature, stats in data.items():
        for stat, value in stats.items():
            flat_data[f'{feature}_{stat}'] = value
    # Convert the flat dictionary to a DataFrame with a single row
    df = pd.DataFrame(flat_data, index=[0])
    return df

# Function to summarize every 50 rows with overlapping intervals, sliding by 12 rows
def summarize_consecutive_rows(df, num_cols, summary_interval=50, slide_step=12):
    summaries = []
    summary_df = pd.DataFrame()
    counter = 1

    for start_idx in range(0, len(df), slide_step):
        # Select a slice of 50 rows (or fewer for the last chunk)
        selected = df.iloc[start_idx:start_idx + summary_interval]
        
        # Stop if there are no more rows to process
        if selected.empty:
            break
            
        summary_stats = {}

        # Calculate statistics for each numerical column
        for col in num_cols:
            stats = selected[col].describe().to_dict()
            summary_stats[col] = stats

        # Convert to DataFrame row format
        summary_row = dict_to_df(summary_stats)

        # Add start and end time for the chunk
        summary_row['start_time'] = selected['time'].iloc[0]
        summary_row['end_time'] = selected['time'].iloc[-1]

        # Add chunk number
        summary_row['eventid'] = f"{trialid}_chunk_{counter}"

        # Get rid of all columns that contain 'count' or '%' in the name
        summary_row = summary_row.loc[:, ~summary_row.columns.str.contains('count|%', regex=True)]

        # Append to the main DataFrame
        summary_df = pd.concat([summary_df, summary_row], ignore_index=True)

        counter += 1

    return summary_df

# Main DataFrame to store all summaries
dataset_features = pd.DataFrame()

for file in samplingfiles:
    df = pd.read_csv(file)
    trialid = file.split('\\')[-1].split('.')[0]

    # Define numerical columns (excluding 'time' and 'change' if present)
    num_cols = [col for col in df.select_dtypes(include=np.number).columns if col != 'change' and col != 'time']

    # Summarize data in intervals of 50 rows, sliding by 12 rows
    summary_df = summarize_consecutive_rows(df, num_cols, summary_interval=50, slide_step=12)

    # Add trial ID to the DataFrame
    summary_df['trialid'] = trialid

    # Drop columns with all NA values
    summary_df = summary_df.dropna(axis=1, how='all')

    # Save as a CSV file
    summary_df.to_csv(chunked_folder + trialid + '_chunked_SW.csv', index=False)

# %%
df
# Out:
#         time      COPc   TrialID  pelvis_tilt_moment  pelvis_list_moment  \
# 0        0.0  0.000185  0_1_2_p0           -2.755942           28.756258
# 1        2.0  0.000245  0_1_2_p0           -2.438810           28.622313
# 2        4.0  0.000294  0_1_2_p0           -2.121678           28.488367
# 3        6.0  0.000329  0_1_2_p0           -1.804546           28.354421
# 4        8.0  0.000353  0_1_2_p0           -1.487414           28.220475
# ...      ...       ...       ...                 ...                 ...
# 1383  2766.0  0.000442  0_1_2_p0            2.397586            1.364340
# 1384  2768.0  0.000558  0_1_2_p0            2.397586            1.364340
# 1385  2770.0  0.000696  0_1_2_p0            2.397586            1.364340
# 1386  2772.0  0.000857  0_1_2_p0            2.397586            1.364340
# 1387  2774.0  0.001044  0_1_2_p0            2.397586            1.364340
#
#       pelvis_rotation_moment  pelvis_tx_force  pelvis_ty_force  \
# 0                  -3.855341        -9.592773       614.805034
# 1                  -3.443759       -10.480074       615.372662
# 2                  -3.032176       -11.367376       615.940291
# 3                  -2.620594       -12.254678       616.507919
# 4                  -2.209012       -13.141980       617.075548
# ...                      ...              ...              ...
# 1383                5.163053        -1.249049       620.347915
# 1384                5.163053        -1.249049       620.347915
# 1385                5.163053        -1.249049       620.347915
# 1386                5.163053        -1.249049       620.347915
# 1387                5.163053        -1.249049       620.347915
#
#       pelvis_tz_force  hip_flexion_r_moment  ...  LwristLhipDistance_z  \
# 0          -12.038132            -37.863982  ...              8.691014
# 1          -11.188778            -38.029734  ...              8.685207
# 2          -10.339424            -38.195487  ...              8.679401
# 3           -9.490071            -38.361239  ...              8.673594
# 4           -8.640717            -38.526991  ...              8.667788
# ...               ...                   ...  ...                   ...
# 1383       -10.488675            -39.016497  ...             -2.525428
# 1384       -10.488675            -39.016497  ...             -2.525428
# 1385       -10.488675            -39.016497  ...             -2.525428
# 1386       -10.488675            -39.016497  ...             -2.525428
# 1387       -10.488675            -39.016497  ...             -2.525428
#
#       LwristRhipDistance_x  LwristRhipDistance_y  LwristRhipDistance_z  \
# 0                19.582542            -10.039997              8.621602
# 1                19.591826            -10.034142              8.608820
# 2                19.601109            -10.028287              8.596039
# 3                19.610393            -10.022432              8.583257
# 4                19.619676            -10.016577              8.570476
# ...                    ...                   ...                   ...
# 1383             31.622065              8.325428             -0.620805
# 1384             31.622065              8.325428             -0.620805
# 1385             31.622065              8.325428             -0.620805
# 1386             31.622065              8.325428             -0.620805
# 1387             31.622065              8.325428             -0.620805
#
#       HeadRhipDistance_x  HeadRhipDistance_y  HeadRhipDistance_z  \
# 0               2.947248           -9.319774           77.742651
# 1               2.948084           -9.313385           77.730512
# 2               2.948921           -9.306996           77.718374
# 3               2.949758           -9.300607           77.706235
# 4               2.950595           -9.294218           77.694096
# ...                  ...                 ...                 ...
# 1383            3.045829          -10.888335           74.455483
# 1384            3.045829          -10.888335           74.455483
# 1385            3.045829          -10.888335           74.455483
# 1386            3.045829          -10.888335           74.455483
# 1387            3.045829          -10.888335           74.455483
#
#       HeadRankleDistance_x  HeadRankleDistance_y  HeadRankleDistance_z
# 0                -3.442070            -18.529530            158.110047
# 1                -3.442533            -18.522946            158.106180
# 2                -3.442996            -18.516361            158.102313
# 3                -3.443458            -18.509776            158.098446
# 4                -3.443921            -18.503192            158.094579
# ...                    ...                   ...                   ...
# 1383             -3.153954            -21.385561            156.861994
# 1384             -3.153954            -21.385561            156.861994
# 1385             -3.153954            -21.385561            156.861994
# 1386             -3.153954            -21.385561            156.861994
# 1387             -3.153954            -21.385561            156.861994
#
# [1388 rows x 392 columns]

# %%
file

# %%
summary_df
# Out:
#      COPc_mean  COPc_std  COPc_min  COPc_max  pelvis_tilt_moment_mean  \
# 0     0.000319  0.000045  0.000185  0.000374                 2.823243
# 1     0.000264  0.000103  0.000037  0.000373                 4.255155
# 2     0.000215  0.000131  0.000019  0.000373                 4.682679
# 3     0.000184  0.000111  0.000019  0.000373                 4.251187
# 4     0.000124  0.000070  0.000019  0.000257                 3.135539
# ..         ...       ...       ...       ...                      ...
# 111   0.000124  0.000039  0.000070  0.000263                 1.558032
# 112   0.000206  0.000205  0.000070  0.001044                 1.776158
# 113   0.000234  0.000235  0.000070  0.001044                 2.003217
# 114   0.000279  0.000291  0.000070  0.001044                 2.297744
# 115   0.000550  0.000298  0.000197  0.001044                 2.397586
#
#      pelvis_tilt_moment_std  pelvis_tilt_moment_min  pelvis_tilt_moment_max  \
# 0                  2.493456               -2.755942                5.258982
# 1                  1.200254                1.061957                5.258982
# 2                  0.519964                3.510468                5.258982
# 3                  1.099776                1.650300                5.258982
# 4                  1.806628               -0.494651                5.258982
# ..                      ...                     ...                     ...
# 111                0.477531                1.114530                2.397586
# 112                0.518153                1.120982                2.397586
# 113                0.419953                1.284238                2.397586
# 114                0.164262                1.898377                2.397586
# 115                0.000000                2.397586                2.397586
#
#      pelvis_list_moment_mean  pelvis_list_moment_std  ...  \
# 0                  28.172777                0.926994  ...
# 1                  29.001953                1.691130  ...
# 2                  30.458142                2.139742  ...
# 3                  32.083622                2.067181  ...
# 4                  33.327615                1.426849  ...
# ..                       ...                     ...  ...
# 111                12.902481                7.231593  ...
# 112                 9.157240                6.784042  ...
# 113                 5.986522                5.014515  ...
# 114                 2.481237                1.837547  ...
# 115                 1.364340                0.000000  ...
#
#      HeadRankleDistance_y_min  HeadRankleDistance_y_max  \
# 0                  -18.529530                -18.180545
# 1                  -18.443930                -18.093430
# 2                  -18.358330                -18.021870
# 3                  -18.272729                -18.013578
# 4                  -18.192156                -18.013578
# ..                        ...                       ...
# 111                -21.740338                -21.385561
# 112                -21.635724                -21.385561
# 113                -21.542482                -21.385561
# 114                -21.438626                -21.385561
# 115                -21.385561                -21.385561
#
#      HeadRankleDistance_z_mean  HeadRankleDistance_z_std  \
# 0                   158.007727                  0.061283
# 1                   157.957210                  0.061152
# 2                   157.906075                  0.062859
# 3                   157.856345                  0.060272
# 4                   157.817484                  0.046263
# ..                         ...                       ...
# 111                 157.071441                  0.155520
# 112                 156.986132                  0.117044
# 113                 156.927562                  0.073851
# 114                 156.876435                  0.023760
# 115                 156.861994                  0.000000
#
#      HeadRankleDistance_z_min  HeadRankleDistance_z_max  start_time  end_time  \
# 0                  157.905098                158.110047         0.0      98.0
# 1                  157.853487                158.059777        24.0     122.0
# 2                  157.798187                158.009506        48.0     146.0
# 3                  157.770362                157.959235        72.0     170.0
# 4                  157.770362                157.908965        96.0     194.0
# ..                        ...                       ...         ...       ...
# 111                156.861994                157.344763      2664.0    2762.0
# 112                156.861994                157.202408      2688.0    2774.0
# 113                156.861994                157.075526      2712.0    2774.0
# 114                156.861994                156.934203      2736.0    2774.0
# 115                156.861994                156.861994      2760.0    2774.0
#
#                                  eventid                    trialid
# 0      sampling_dataset_0_1_2_p0_chunk_1  sampling_dataset_0_1_2_p0
# 1      sampling_dataset_0_1_2_p0_chunk_2  sampling_dataset_0_1_2_p0
# 2      sampling_dataset_0_1_2_p0_chunk_3  sampling_dataset_0_1_2_p0
# 3      sampling_dataset_0_1_2_p0_chunk_4  sampling_dataset_0_1_2_p0
# 4      sampling_dataset_0_1_2_p0_chunk_5  sampling_dataset_0_1_2_p0
# ..                                   ...                        ...
# 111  sampling_dataset_0_1_2_p0_chunk_112  sampling_dataset_0_1_2_p0
# 112  sampling_dataset_0_1_2_p0_chunk_113  sampling_dataset_0_1_2_p0
# 113  sampling_dataset_0_1_2_p0_chunk_114  sampling_dataset_0_1_2_p0
# 114  sampling_dataset_0_1_2_p0_chunk_115  sampling_dataset_0_1_2_p0
# 115  sampling_dataset_0_1_2_p0_chunk_116  sampling_dataset_0_1_2_p0
#
# [116 rows x 1548 columns]
