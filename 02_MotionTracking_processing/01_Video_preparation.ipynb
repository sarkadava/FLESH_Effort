# %% [markdown]
# # Motion tracking I: Preparation of videos
#
# In the previous part XXX, we have prepared all the videos into trial-sized files that we can use for motion capture. However, during the experimental recording, we have concatenated the three cameras into one file. Now we need to cut these videos into three and prepare them into folders as OpenPose (and later Pose2sim) requires.
#
# We will do the same for calibration videos.

# %%
#| code-fold: true

import os
import cv2
import glob

# Currect folder
curfolder = os.getcwd()

# Videodata 
videodata = curfolder + '\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials'
outputfolder = curfolder + '\\projectdata_test\\'

# Load in the videos (avi)
videos = []
for file in os.listdir(videodata):
    if file.endswith(".avi"):
        videos.append(os.path.join(videodata, file))

print(videos[0:10])

# Calibration videos are in rawdata folder
calibfolder = curfolder + '\\..\\00_RAWDATA\\'

# Extrinsic calibration
videos_ex = glob.glob(calibfolder + '*\\*extrinsics.avi', recursive=True)

# Intrinsic calibration
video_in = glob.glob(calibfolder + '*\\*intrinsics.avi', recursive=True)
# Out:
# ['e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_tpose_0_MyWebcamFrameStream_nominal_srate500_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_tpose_1_MyWebcamFrameStream_nominal_srate500_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_pr_0_p0_bloem_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_3_p0_vechten_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_4_p0_ademen_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_5_p0_bijten_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_6_p0_zoemen_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_7_p0_fluisteren_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_11_p1_eten_geluiden_video_raw.avi', 'e:\\FLESH_ContinuousBodilyEffort\\02_MotionTracking\\..\\01_XDF_processing\\data\\Data_processed\\Data_trials\\0_1_trial_12_p1_ei_geluiden_video_raw.avi']

# %%
#| code-fold: true

def split_camera_views(input_file, output_files):
    cap = cv2.VideoCapture(input_file)

    # Divide the width by 3 to get each camera separately
    num_cameras = 3
    width_per_camera = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) // num_cameras
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_rate = int(cap.get(cv2.CAP_PROP_FPS))

    # Create VideoWriters for each camera
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out_cam1 = cv2.VideoWriter(output_files[0], fourcc, frame_rate, (width_per_camera, height))
    out_cam2 = cv2.VideoWriter(output_files[1], fourcc, frame_rate, (width_per_camera, height))
    out_cam3 = cv2.VideoWriter(output_files[2], fourcc, frame_rate, (width_per_camera, height))

    while True:
        ret, frame = cap.read()

        # Check if the frame is None (end of video)
        if frame is None:
            break

        # Break the frame into three parts
        camera1_frame = frame[:, :width_per_camera, :]
        camera2_frame = frame[:, width_per_camera:2*width_per_camera, :]
        camera3_frame = frame[:, 2*width_per_camera:, :]

        # Display each camera view separately (optional)
        cv2.imshow('Camera 1', camera1_frame)
        cv2.imshow('Camera 2', camera2_frame)
        cv2.imshow('Camera 3', camera3_frame)

        # Write frames to video files
        out_cam1.write(camera1_frame)
        out_cam2.write(camera2_frame)
        out_cam3.write(camera3_frame)

        if cv2.waitKey(1) == 27:
            break

    # Release VideoWriters and VideoCapture
    out_cam1.release()
    out_cam2.release()
    out_cam3.release()
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# We will first start with the trial videos, as they require a bit different structuring into folders than the calibration videos. Each video-tryad will be saved into following structure */sessionID/pcnID/trialID/raw-22* with its original name and identificator of each camera (i.e., 1-3)

# %%
# Loop over files in folder and split them
for file in videos:
    print("working on file: "+ file)

    # Get the name of the file without the extension
    filename = os.path.splitext(os.path.basename(file))[0]
    
    # Get trialID
    # If it's a tpose, the name goes a bit differently than the rest
    if 'tpose' in filename: 
        trialID = filename.split("_")[0] + "_" + filename.split("_")[1] + "_" + filename.split("_")[2]+ "_p" + filename.split("_")[3]
    else:
        # session, part, trial number and participant as trial ID
        trialID = filename.split("_")[0] + "_" + filename.split("_")[1] + "_" + filename.split("_")[3] + "_" + filename.split("_")[4]

    # Get sessionID
    sessionID = 'Session' + '_' + filename.split("_")[0] + "_" + filename.split("_")[1]

    # If a sessionID folder doesn't exist yet, create it
    if not os.path.exists(os.path.join(outputfolder, sessionID)):
        os.makedirs(os.path.join(outputfolder, sessionID))    

    # Same for folders P0 and P1
    if not os.path.exists(os.path.join(outputfolder, sessionID, 'P0')):
        os.makedirs(os.path.join(outputfolder, sessionID, 'P0'))
    if not os.path.exists(os.path.join(outputfolder, sessionID, 'P1')):
        os.makedirs(os.path.join(outputfolder, sessionID, 'P1'))

    # Now trialID folder within respective participant
    if 'p0' in filename or 'tpose_0' in filename:
        try:
            os.makedirs(os.path.join(outputfolder, sessionID, 'P0', trialID))
            # Inside this folder, create empty folder 'raw-2d'
            os.makedirs(os.path.join(outputfolder, sessionID, 'P0', trialID, 'raw-2d'))
        except FileExistsError:
            continue

        # This is how the final video is named
        output_files = [
            os.path.join(outputfolder, sessionID, 'P0', trialID, 'raw-2d', filename + '_cam1.avi'),
            os.path.join(outputfolder, sessionID, 'P0', trialID, 'raw-2d', filename + '_cam2.avi'),
            os.path.join(outputfolder, sessionID, 'P0', trialID, 'raw-2d', filename + '_cam3.avi')
        ]

    elif 'p1' in filename or 'tpose_1' in filename:
        try:
            os.makedirs(os.path.join(outputfolder, sessionID, 'P1', trialID))
            os.makedirs(os.path.join(outputfolder, sessionID, 'P1', trialID, 'raw-2d'))
        except FileExistsError:
            continue    

        # This is how the final video is named
        output_files = [
            os.path.join(outputfolder, sessionID, 'P1', trialID, 'raw-2d', filename + '_cam1.avi'),
            os.path.join(outputfolder, sessionID, 'P1', trialID, 'raw-2d', filename + '_cam2.avi'),
            os.path.join(outputfolder, sessionID, 'P1', trialID, 'raw-2d', filename + '_cam3.avi')
        ]

    else:
        try:
            os.makedirs(os.path.join(outputfolder, sessionID, trialID))
            os.makedirs(os.path.join(outputfolder, sessionID, trialID, 'raw-2d'))
        except FileExistsError:
            continue

        output_files = [
            os.path.join(outputfolder, sessionID, trialID, 'raw-2d', filename + '_cam1.avi'),
            os.path.join(outputfolder, sessionID, trialID, 'raw-2d', filename + '_cam2.avi'),
            os.path.join(outputfolder, sessionID, trialID, 'raw-2d', filename + '_cam3.avi')]

    # Split the camera views
    split_camera_views(file, output_files)
# Out:
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_tpose_0_MyWebcamFrameStream_nominal_srate500_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_tpose_1_MyWebcamFrameStream_nominal_srate500_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_0_p0_bloem_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_3_p0_vechten_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_4_p0_ademen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_5_p0_bijten_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_6_p0_zoemen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_7_p0_fluisteren_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_11_p1_eten_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_12_p1_ei_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_13_p1_zwemmen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_14_p1_snel_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_15_p1_regen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_16_p1_boos_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_17_p1_luidruchtig_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_19_p0_olifant_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_20_p0_verdrietig_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_21_p0_koud_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_22_p0_staan_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_23_p0_stil_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_24_p0_lopen_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_25_p0_bang_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_26_p0_gooien_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_27_p1_haasten_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_28_p1_gek_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_29_p1_rennen_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_30_p1_likken_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_31_p1_klein_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_32_p1_onweer_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_33_p1_man_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_34_p1_springen_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_35_p1_langzaam_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_36_p0_snijden_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_37_p0_comfortabel_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_38_p0_kind_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_39_p0_hoorn_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_40_p0_kotsen_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_41_p0_dood_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_42_p0_drinken_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_43_p0_sterk_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_44_p0_oud_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_45_p1_koken_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_46_p1_slang_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_47_p1_slang_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_48_p1_zuur_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_49_p1_niet_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_50_p1_weten_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_51_p1_slaan_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_52_p1_hond_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_53_p1_vangen_gebaren_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_0_p0_juichen_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_1_p0_zingen_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_2_p0_vrouw_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_3_p0_vrouw_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_4_p0_vrouw_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_5_p0_verbranden_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_6_p0_verbranden_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_7_p0_verbranden_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_8_p0_ik_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_9_p0_kauwen_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_10_p0_vliegen_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_11_p0_vliegen_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_12_p0_vliegen_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_13_p0_misschien_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_14_p0_misschien_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_15_p0_misschien_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_16_p0_bliksem_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_17_p0_bliksem_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_18_p0_bliksem_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_19_p1_glimlach_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_20_p1_glimlach_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_21_p1_glimlach_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_22_p1_klok_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_23_p1_groot_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_24_p1_groot_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_25_p1_groot_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_26_p1_hoog_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_27_p1_hoog_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_28_p1_hoog_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_29_p1_blij_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_30_p1_blij_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_31_p1_blij_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_32_p1_vis_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_33_p1_ruiken_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_34_p1_wind_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_35_p1_heet_combinatie_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_36_p1_heet_combinatie_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_37_p1_heet_combinatie_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_38_p0_fiets_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_39_p0_vliegtuig_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_40_p0_vliegtuig_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_41_p0_vogel_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_42_p0_kruipen_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_43_p0_water_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_44_p0_water_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_45_p0_water_gebaren_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_46_p0_vuur_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_47_p0_goed_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_48_p0_goed_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_49_p0_horen_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_50_p0_ver_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_51_p0_ver_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_52_p0_ver_gebaren_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_53_p1_geheim_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_54_p1_geheim_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_55_p1_geheim_gebaren_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_56_p1_telefoon_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_57_p1_blazen_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_58_p1_geven_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_59_p1_geven_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_60_p1_kat_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_61_p1_lachen_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_62_p1_zoet_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_63_p1_zoet_gebaren_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_64_p1_zoet_gebaren_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_65_p1_slapen_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_66_p1_berg_gebaren_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_67_p0_ziek_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_68_p0_ziek_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_69_p0_ziek_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_70_p0_zwaaien_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_71_p0_zwaaien_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_72_p0_zwaaien_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_73_p0_geur_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_74_p0_geur_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_75_p0_geur_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_76_p0_vlieg_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_77_p0_vlieg_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_78_p0_vlieg_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_79_p0_scherp_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_80_p0_scherp_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_81_p0_scherp_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_82_p0_staart_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_83_p0_staart_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_84_p0_staart_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_85_p0_vallen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_86_p0_piepen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_87_p0_piepen_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_88_p0_piepen_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_89_p0_jagen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_90_p0_jagen_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_91_p0_jagen_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_92_p1_bal_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_93_p1_bal_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_94_p1_bal_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_95_p1_sneeuw_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_96_p1_sneeuw_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_pr_97_p1_sneeuw_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_98_p1_zwaar_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_99_p1_zwaar_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_100_p1_zwaar_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_101_p1_grommen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_102_p1_zout_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_103_p1_zout_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_104_p1_zout_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_105_p1_zuigen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_106_p1_zuigen_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_107_p1_zuigen_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_108_p1_dik_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_109_p1_dik_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_110_p1_dik_geluiden_c2_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_111_p1_ziek_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_112_p1_ziek_geluiden_c1_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_2_trial_113_p1_huilen_geluiden_c0_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_1_p0_dansen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_10_p1_auto_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_18_p0_snel_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_2_p0_bitter_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_8_p0_walgen_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_9_p1_langzaam_geluiden_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_34_p1_springen_combinatie_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_1_p0_dansen_geluiden_corrected_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_9_p1_langzaam_geluiden_corrected_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_10_p1_auto_geluiden_corrected_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_pr_18_p0_snel_combinatie_corrected_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_2_p0_bitter_geluiden_corrected_video_raw.avi
# Folder already exists
# working on file: e:\FLESH_ContinuousBodilyEffort\02_MotionTracking\..\01_XDF_processing\data\Data_processed\Data_trials\0_1_trial_8_p0_walgen_geluiden_corrected_video_raw.avi
# Folder already exists

# %% [markdown]
# Now we also need to cut the video for calibration.
#
# In the very beginning, we need to calibrate intrinsic parameters of the cameras (i.e., XXX). This needs to be done only once, and for that purpose we have special calibration video that is optimized for a low intrinsic error. For extrinsic parameters, we have calibration per each session.

# %%
# Loop over files in folder and split them
for file in video_in:
    # Get the name of the file without the extension
    filename = os.path.splitext(os.path.basename(file))[0]
    
    # sessionID
    sessionID = filename.split("_")[0]
    # note that we save it only to session 0_1 because intrinsic calibration needs to be done only once
    sessionID = 'Session_' + sessionID + "_1" 

    # Inside this folder, create empty folder 'calibration'
    if not os.path.exists(os.path.join(outputfolder, sessionID, 'calibration')):
        os.makedirs(os.path.join(outputfolder, sessionID, 'calibration'))
    # Inside, make three folders: cam1, cam2, cam3
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics', 'cam1'))
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics','cam2'))
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics','cam3'))
    
    # Create the output file names
    output_files = [
        os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics','cam1', filename + '_cam1.avi'),
        os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics','cam2', filename + '_cam2.avi'),
        os.path.join(outputfolder, sessionID, 'calibration', 'intrinsics','cam3', filename + '_cam3.avi')
    ]
    
    # Split the camera views
    split_camera_views(file, output_files)

# %% [markdown]
# Now we can also cut the video for extrinsic calibration

# %%
# Loop over files in folder and split them
for file in videos_ex:
    # Get the name of the file without the extension
    filename = os.path.splitext(os.path.basename(file))[0]

    sessionID = filename.split("_")[0]
    # Note that we save it only to session x_1 because then we will just copy the finished calibratio toml file
    sessionID = 'Session_' + sessionID + "_1" 

    # Inside this folder, create empty folder 'calibration' 
    if not os.path.exists(os.path.join(outputfolder, sessionID, 'calibration')):
        os.makedirs(os.path.join(outputfolder, sessionID, 'calibration'))

    # Inside, make three folders: cam1, cam2, cam3
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics', 'cam1'))
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics','cam2'))
    os.makedirs(os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics','cam3'))
    
    # Create the output file names
    output_files = [
        os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics','cam1', filename + '_cam1.avi'),
        os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics','cam2', filename + '_cam2.avi'),
        os.path.join(outputfolder, sessionID, 'calibration', 'extrinsics','cam3', filename + '_cam3.avi')
    ]
    
    # Split the camera views
    split_camera_views(file, output_files)

# %% [markdown]
# Now we are ready to proceed to motion tracking with OpenPose.
