# %% [markdown]
# # Preparation

# %%
import os
import glob
import pandas as pd
from transformers import BertTokenizer, BertModel
from transformers import RobertaTokenizer, RobertaForSequenceClassification
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import openpyxl


curfolder = os.getcwd()
answerfolder = curfolder + '/answer_data/'
answerfiles = glob.glob(answerfolder + '*.csv')

# load in one file
df = pd.read_csv(answerfiles[0])
# add a column exp and set values everywhere to 1 - tp keep track what part is it
df['exp'] = 1
df2 = pd.read_csv(answerfiles[1])
df2['exp'] = 2

# concept list
df_concepts = pd.read_excel(answerfolder + '/conceptlist_info.xlsx')

# %% [markdown]
# # Function for BERT embeddings

# %%
# Function to get BERT embeddings
def get_word_embedding(word):
    inputs = tokenizer(word, return_tensors='pt')
    with torch.no_grad():
        outputs = model(**inputs)
    # Extract the embeddings of the [CLS] token, which is the aggregate representation
    embeddings = outputs.last_hidden_state[:, 0, :].squeeze()
    return embeddings

# %% [markdown]
# # BERT for English

# %% [markdown]
# ## Preparation

# %%
# merge df and df 2
df_all = pd.concat([df, df2], ignore_index=True)

# keep only columns word and answer
df = df_all[['word', 'answer', 'exp']]

# in df_concepts, keep only English and Dutch
df_concepts = df_concepts[['English', 'Dutch']]

# rename Dutch to word
df_concepts = df_concepts.rename(columns={'Dutch': 'word'})

# merge df and df_concepts on word
df = pd.merge(df, df_concepts, on='word', how='left')

# show rows where English is NaN
df[df['English'].isnull()]

# add translations manually for each
df.loc[df['word'] == 'bloem', 'English'] = 'flower'
df.loc[df['word'] == 'dansen', 'English'] = 'to dance'
df.loc[df['word'] == 'auto', 'English'] = 'car'
df.loc[df['word'] == 'olifant', 'English'] = 'elephant'
df.loc[df['word'] == 'comfortabel', 'English'] = 'comfortable'
df.loc[df['word'] == 'bal', 'English'] = 'ball'
df.loc[df['word'] == 'haasten', 'English'] = 'to hurry'
df.loc[df['word'] == 'gek', 'English'] = 'crazy'
df.loc[df['word'] == 'snijden', 'English'] = 'to cut'
df.loc[df['word'] == 'koken', 'English'] = 'to cook'
df.loc[df['word'] == 'juichen', 'English'] = 'to cheer'
df.loc[df['word'] == 'zingen', 'English'] = 'to sing'
df.loc[df['word'] == 'glimlach', 'English'] = 'smile'
df.loc[df['word'] == 'klok', 'English'] = 'clock'
df.loc[df['word'] == 'fiets', 'English'] = 'bicycle'
df.loc[df['word'] == 'vliegtuig', 'English'] = 'airplane'
df.loc[df['word'] == 'geheim', 'English'] = 'secret'
df.loc[df['word'] == 'telefoon', 'English'] = 'telephone'
df.loc[df['word'] == 'zwaaien', 'English'] = 'to wave'
df.loc[df['word'] == 'sneeuw', 'English'] = 'snow'

# %% [markdown]
# ## BERT
#
# Models here: https://huggingface.co/transformers/v3.3.1/pretrained_models.html

# %%
meanings_en = list(df['English'])
len(meanings_en)

answers_nl = list(df['answer'])
answers_nl
len(answers_nl)

answers_en = ['party', 'to cheer', 'tasty', 'to shoot', 'to breathe', 'zombie', 'bee', 'sea', 'dirty', 'tasty', 'car', 'to eat', 'to eat', 'to blow', 'hose', 'hose', 'to annoy', 'to make noise', 'to make noise', 'to run away', 'elephant', 'to cry', 'cold', 'outfit', 'silence', 'to ski', 'wrong', 'to play basketball', 'to search', 'disturbed', 'to run', 'to lick', 'to lift', 'lightning', 'to think', 'to jump', 'to fall', 'to write', 'to dance', 'shoulder height', 'horn', 'dirty', 'boring', 'to drink', 'strong', 'elderly', 'to mix', 'fish', 'fish', 'dirty', 'wrong', 'smart', 'to box', 'to box', 'dog', 'to catch', 'to cheer', 'to sing', 'pregnant', 'hair', 'to shower', 'pain', 'burnt', 'hot', 'I', 'to chew', 'bird', 'airplane', 'to fly', 'to think', 'to choose', 'to doubt', 'graffiti', 'fireworks', 'bomb', 'to smile', 'to laugh', 'smile', 'clock', 'to wonder', 'height', 'big', 'height', 'space', 'to misjudge', 'to wait', 'satisfied', 'happy', 'fish', 'to smell', 'wind', 'pain', 'to burn', 'hot', 'to cycle', 'to fly', 'airplane', 'bird', 'to crawl', 'to drink', 'waterfall', 'water', 'fire', 'top', 'good', 'to hear', 'to point', 'distance', 'there', 'to whisper', 'quiet', 'to be silent', 'telephone', 'to blow', 'to distribute', 'to give', 'cat', 'to laugh', 'tasty', 'to eat', 'yummy', 'to sleep', 'mountain', 'dirty', 'to vomit', 'to be disgusted', 'to greet', 'hello', 'goodbye', 'to smell', 'nose', 'odor', 'to fly', 'fireworks', 'to blow', 'to cut', 'pain', 'hot', 'to slurp', 'to throw', 'to fall', 'to fall', 'whistle', 'heartbeat', 'mouse', 'to hit', 'to catch', 'to grab', 'to throw', 'to fall', 'to shoot', 'circus', 'trunk', 'to fall', 'to fight', 'pain', 'to push open', 'to growl', 'to cut', 'to eat', 'knife', 'to slurp', 'to drink', 'drink', 'to eat', 'delicious', 'tasty', 'to cough', 'sick', 'to cry', 'to cry']
len(answers_en)

# add those to df as answers_en
df['answer_en'] = answers_en

tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
model = BertModel.from_pretrained('bert-large-cased')

# Calculate embeddings
guessed_embeddings_en = [get_word_embedding(word) for word in meanings_en]
answer_embeddings_en = [get_word_embedding(word) for word in answers_en]

# Calculate cosine similarities
similarities_en = [cosine_similarity([guessed_emb], [answer_emb])[0][0] for guessed_emb, answer_emb in zip(guessed_embeddings_en, answer_embeddings_en)]

# Print similarities
for guessed_word, answer, similarity in zip(meanings_en, answers_en, similarities_en):
    print(f"Cosine similarity between '{guessed_word}' and '{answer}': {similarity:.4f}")

# calculate euclidian similarity
def euclidean_similarity(a, b):
    return np.linalg.norm(a - b)

# Calculate euclidean similarities
euclidean_similarities_en = [euclidean_similarity(guessed_emb, answer_emb) for guessed_emb, answer_emb in zip(guessed_embeddings_en, answer_embeddings_en)]

# Print similarities
for guessed_word, answer, similarity in zip(meanings_en, answers_en, euclidean_similarities_en):
    print(f"Euclidean distance between '{guessed_word}' and '{answer}': {similarity:.4f}")

# save both to df
df['cosine_similarity'] = similarities_en
df['euclidean_similarity'] = euclidean_similarities_en
# Out:
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# Cosine similarity between 'flower' and 'party': 0.1611
# Cosine similarity between 'to dance' and 'to cheer': 0.6847
# Cosine similarity between 'bitter' and 'tasty': 0.0824
# Cosine similarity between 'to fight' and 'to shoot': 0.9472
# Cosine similarity between 'to breathe' and 'to breathe': 1.0000
# Cosine similarity between 'to bite' and 'zombie': 0.1149
# Cosine similarity between 'buzz' and 'bee': 0.3036
# Cosine similarity between 'to whisper' and 'sea': 0.2001
# Cosine similarity between 'disgusted' and 'dirty': 0.5769
# Cosine similarity between 'slow' and 'tasty': 0.1721
# Cosine similarity between 'car' and 'car': 1.0000
# Cosine similarity between 'to eat' and 'to eat': 1.0000
# Cosine similarity between 'egg' and 'to eat': 0.7380
# Cosine similarity between 'to swim' and 'to blow': 0.9247
# Cosine similarity between 'fast' and 'hose': 0.2723
# Cosine similarity between 'rain' and 'hose': 0.2141
# Cosine similarity between 'angry' and 'to annoy': 0.1360
# Cosine similarity between 'noisy' and 'to make noise': 0.1098
# Cosine similarity between 'loud' and 'to make noise': 0.1691
# Cosine similarity between 'fast' and 'to run away': 0.2528
# Cosine similarity between 'elephant' and 'elephant': 1.0000
# Cosine similarity between 'sad' and 'to cry': 0.1679
# Cosine similarity between 'cold' and 'cold': 1.0000
# Cosine similarity between 'to stand' and 'outfit': 0.0871
# Cosine similarity between 'silent' and 'silence': 0.4412
# Cosine similarity between 'to walk' and 'to ski': 0.8929
# Cosine similarity between 'scared' and 'wrong': 0.2859
# Cosine similarity between 'to throw' and 'to play basketball': 0.8820
# Cosine similarity between 'to hurry' and 'to search': 0.8485
# Cosine similarity between 'crazy' and 'disturbed': 0.4373
# Cosine similarity between 'to run' and 'to run': 1.0000
# Cosine similarity between 'to lick' and 'to lick': 1.0000
# Cosine similarity between 'small' and 'to lift': 0.4332
# Cosine similarity between 'thunder' and 'lightning': 0.7031
# Cosine similarity between 'male' and 'to think': 0.0202
# Cosine similarity between 'to jump' and 'to jump': 1.0000
# Cosine similarity between 'slow' and 'to fall': 0.2701
# Cosine similarity between 'to cut' and 'to write': 0.9176
# Cosine similarity between 'comfortable' and 'to dance': 0.1682
# Cosine similarity between 'child' and 'shoulder height': 0.5447
# Cosine similarity between 'horn' and 'horn': 1.0000
# Cosine similarity between 'to vomit' and 'dirty': 0.2272
# Cosine similarity between 'dead' and 'boring': 0.5046
# Cosine similarity between 'to drink' and 'to drink': 1.0000
# Cosine similarity between 'strong' and 'strong': 1.0000
# Cosine similarity between 'old' and 'elderly': 0.6563
# Cosine similarity between 'to cook' and 'to mix': 0.9117
# Cosine similarity between 'snake' and 'fish': 0.7221
# Cosine similarity between 'snake' and 'fish': 0.7221
# Cosine similarity between 'sour' and 'dirty': 0.3317
# Cosine similarity between 'not' and 'wrong': 0.1861
# Cosine similarity between 'to know' and 'smart': 0.1778
# Cosine similarity between 'to hit' and 'to box': 0.9191
# Cosine similarity between 'to beat' and 'to box': 0.9502
# Cosine similarity between 'dog' and 'dog': 1.0000
# Cosine similarity between 'to catch' and 'to catch': 1.0000
# Cosine similarity between 'to cheer' and 'to cheer': 1.0000
# Cosine similarity between 'to sing' and 'to sing': 1.0000
# Cosine similarity between 'female' and 'pregnant': 0.6500
# Cosine similarity between 'female' and 'hair': 0.3190
# Cosine similarity between 'female' and 'to shower': 0.0719
# Cosine similarity between 'to burn' and 'pain': 0.2496
# Cosine similarity between 'to burn' and 'burnt': 0.1155
# Cosine similarity between 'to burn' and 'hot': 0.2215
# Cosine similarity between 'I' and 'I': 1.0000
# Cosine similarity between 'to chew' and 'to chew': 1.0000
# Cosine similarity between 'to fly' and 'bird': 0.2492
# Cosine similarity between 'to fly' and 'airplane': 0.0715
# Cosine similarity between 'to fly' and 'to fly': 1.0000
# Cosine similarity between 'maybe' and 'to think': 0.2200
# Cosine similarity between 'maybe' and 'to choose': 0.2977
# Cosine similarity between 'maybe' and 'to doubt': 0.2076
# Cosine similarity between 'lightning' and 'graffiti': 0.1092
# Cosine similarity between 'lightning' and 'fireworks': 0.2245
# Cosine similarity between 'lightning' and 'bomb': 0.4052
# Cosine similarity between 'smile' and 'to smile': 0.0286
# Cosine similarity between 'smile' and 'to laugh': 0.0036
# Cosine similarity between 'smile' and 'smile': 1.0000
# Cosine similarity between 'clock' and 'clock': 1.0000
# Cosine similarity between 'big' and 'to wonder': 0.1252
# Cosine similarity between 'big' and 'height': 0.1225
# Cosine similarity between 'big' and 'big': 1.0000
# Cosine similarity between 'high' and 'height': 0.5245
# Cosine similarity between 'high' and 'space': 0.4020
# Cosine similarity between 'high' and 'to misjudge': 0.2405
# Cosine similarity between 'happy' and 'to wait': 0.1765
# Cosine similarity between 'happy' and 'satisfied': 0.4814
# Cosine similarity between 'happy' and 'happy': 1.0000
# Cosine similarity between 'fish' and 'fish': 1.0000
# Cosine similarity between 'to smell' and 'to smell': 1.0000
# Cosine similarity between 'wind' and 'wind': 1.0000
# Cosine similarity between 'hot' and 'pain': 0.4195
# Cosine similarity between 'hot' and 'to burn': 0.2215
# Cosine similarity between 'hot' and 'hot': 1.0000
# Cosine similarity between 'bicycle' and 'to cycle': 0.1973
# Cosine similarity between 'airplane' and 'to fly': 0.0715
# Cosine similarity between 'airplane' and 'airplane': 1.0000
# Cosine similarity between 'bird' and 'bird': 1.0000
# Cosine similarity between 'to crawl' and 'to crawl': 1.0000
# Cosine similarity between 'water' and 'to drink': 0.1184
# Cosine similarity between 'water' and 'waterfall': 0.4929
# Cosine similarity between 'water' and 'water': 1.0000
# Cosine similarity between 'fire' and 'fire': 1.0000
# Cosine similarity between 'good' and 'top': 0.1539
# Cosine similarity between 'good' and 'good': 1.0000
# Cosine similarity between 'to hear' and 'to hear': 1.0000
# Cosine similarity between 'far' and 'to point': 0.4127
# Cosine similarity between 'far' and 'distance': 0.4979
# Cosine similarity between 'far' and 'there': 0.5528
# Cosine similarity between 'secret' and 'to whisper': 0.1198
# Cosine similarity between 'secret' and 'quiet': 0.3823
# Cosine similarity between 'secret' and 'to be silent': 0.1104
# Cosine similarity between 'telephone' and 'telephone': 1.0000
# Cosine similarity between 'to blow' and 'to blow': 1.0000
# Cosine similarity between 'to give' and 'to distribute': 0.9262
# Cosine similarity between 'to give' and 'to give': 1.0000
# Cosine similarity between 'cat' and 'cat': 1.0000
# Cosine similarity between 'to laugh' and 'to laugh': 1.0000
# Cosine similarity between 'sweet' and 'tasty': 0.0849
# Cosine similarity between 'sweet' and 'to eat': 0.1216
# Cosine similarity between 'sweet' and 'yummy': 0.2006
# Cosine similarity between 'to sleep' and 'to sleep': 1.0000
# Cosine similarity between 'mountain' and 'mountain': 1.0000
# Cosine similarity between 'sick' and 'dirty': 0.4903
# Cosine similarity between 'sick' and 'to vomit': 0.1976
# Cosine similarity between 'sick' and 'to be disgusted': 0.1191
# Cosine similarity between 'to wave' and 'to greet': 0.7675
# Cosine similarity between 'to wave' and 'hello': 0.1038
# Cosine similarity between 'to wave' and 'goodbye': 0.0680
# Cosine similarity between 'odor' and 'to smell': 0.0407
# Cosine similarity between 'odor' and 'nose': 0.3586
# Cosine similarity between 'odor' and 'odor': 1.0000
# Cosine similarity between 'fly' and 'to fly': 0.8627
# Cosine similarity between 'fly' and 'fireworks': 0.0709
# Cosine similarity between 'fly' and 'to blow': 0.8241
# Cosine similarity between 'sharp' and 'to cut': 0.2912
# Cosine similarity between 'sharp' and 'pain': 0.4146
# Cosine similarity between 'sharp' and 'hot': 0.2817
# Cosine similarity between 'tail' and 'to slurp': 0.2705
# Cosine similarity between 'tail' and 'to throw': 0.2661
# Cosine similarity between 'tail' and 'to fall': 0.2341
# Cosine similarity between 'to fall' and 'to fall': 1.0000
# Cosine similarity between 'squeak' and 'whistle': 0.2926
# Cosine similarity between 'squeak' and 'heartbeat': 0.1251
# Cosine similarity between 'squeak' and 'mouse': 0.7375
# Cosine similarity between 'to hunt' and 'to hit': 0.9236
# Cosine similarity between 'to hunt' and 'to catch': 0.9527
# Cosine similarity between 'to hunt' and 'to grab': 0.9054
# Cosine similarity between 'ball' and 'to throw': 0.1268
# Cosine similarity between 'ball' and 'to fall': 0.1228
# Cosine similarity between 'ball' and 'to shoot': 0.1280
# Cosine similarity between 'snow' and 'circus': 0.1990
# Cosine similarity between 'snow' and 'trunk': 0.3340
# Cosine similarity between 'snow' and 'to fall': 0.1634
# Cosine similarity between 'heavy' and 'to fight': 0.7363
# Cosine similarity between 'heavy' and 'pain': 0.2941
# Cosine similarity between 'heavy' and 'to push open': 0.6425
# Cosine similarity between 'to growl' and 'to growl': 1.0000
# Cosine similarity between 'salt' and 'to cut': 0.8480
# Cosine similarity between 'salt' and 'to eat': 0.8154
# Cosine similarity between 'salt' and 'knife': 0.1642
# Cosine similarity between 'to suck' and 'to slurp': 0.9426
# Cosine similarity between 'to suck' and 'to drink': 0.9100
# Cosine similarity between 'to suck' and 'drink': 0.2019
# Cosine similarity between 'thick' and 'to eat': 0.7944
# Cosine similarity between 'thick' and 'delicious': 0.1821
# Cosine similarity between 'thick' and 'tasty': 0.8075
# Cosine similarity between 'sick' and 'to cough': 0.1318
# Cosine similarity between 'sick' and 'sick': 1.0000
# Cosine similarity between 'to cry' and 'to cry': 1.0000
# Cosine similarity between 'to weep' and 'to cry': 0.8268
# Euclidean distance between 'flower' and 'party': 23.5745
# Euclidean distance between 'to dance' and 'to cheer': 12.5450
# Euclidean distance between 'bitter' and 'tasty': 26.2849
# Euclidean distance between 'to fight' and 'to shoot': 6.1242
# Euclidean distance between 'to breathe' and 'to breathe': 0.0000
# Euclidean distance between 'to bite' and 'zombie': 23.3103
# Euclidean distance between 'buzz' and 'bee': 16.8901
# Euclidean distance between 'to whisper' and 'sea': 21.4615
# Euclidean distance between 'disgusted' and 'dirty': 15.1900
# Euclidean distance between 'slow' and 'tasty': 24.5636
# Euclidean distance between 'car' and 'car': 0.0000
# Euclidean distance between 'to eat' and 'to eat': 0.0000
# Euclidean distance between 'egg' and 'to eat': 13.6740
# Euclidean distance between 'to swim' and 'to blow': 7.6978
# Euclidean distance between 'fast' and 'hose': 17.7647
# Euclidean distance between 'rain' and 'hose': 19.9029
# Euclidean distance between 'angry' and 'to annoy': 23.5829
# Euclidean distance between 'noisy' and 'to make noise': 24.0433
# Euclidean distance between 'loud' and 'to make noise': 23.5536
# Euclidean distance between 'fast' and 'to run away': 19.1401
# Euclidean distance between 'elephant' and 'elephant': 0.0000
# Euclidean distance between 'sad' and 'to cry': 19.3547
# Euclidean distance between 'cold' and 'cold': 0.0000
# Euclidean distance between 'to stand' and 'outfit': 23.7037
# Euclidean distance between 'silent' and 'silence': 17.1670
# Euclidean distance between 'to walk' and 'to ski': 9.5652
# Euclidean distance between 'scared' and 'wrong': 18.4768
# Euclidean distance between 'to throw' and 'to play basketball': 9.8014
# Euclidean distance between 'to hurry' and 'to search': 10.0653
# Euclidean distance between 'crazy' and 'disturbed': 17.3241
# Euclidean distance between 'to run' and 'to run': 0.0000
# Euclidean distance between 'to lick' and 'to lick': 0.0000
# Euclidean distance between 'small' and 'to lift': 18.7481
# Euclidean distance between 'thunder' and 'lightning': 12.1897
# Euclidean distance between 'male' and 'to think': 23.7883
# Euclidean distance between 'to jump' and 'to jump': 0.0000
# Euclidean distance between 'slow' and 'to fall': 21.9170
# Euclidean distance between 'to cut' and 'to write': 8.5725
# Euclidean distance between 'comfortable' and 'to dance': 19.5431
# Euclidean distance between 'child' and 'shoulder height': 15.2116
# Euclidean distance between 'horn' and 'horn': 0.0000
# Euclidean distance between 'to vomit' and 'dirty': 19.2591
# Euclidean distance between 'dead' and 'boring': 14.6642
# Euclidean distance between 'to drink' and 'to drink': 0.0000
# Euclidean distance between 'strong' and 'strong': 0.0000
# Euclidean distance between 'old' and 'elderly': 12.9870
# Euclidean distance between 'to cook' and 'to mix': 8.6165
# Euclidean distance between 'snake' and 'fish': 11.8608
# Euclidean distance between 'snake' and 'fish': 11.8608
# Euclidean distance between 'sour' and 'dirty': 18.1569
# Euclidean distance between 'not' and 'wrong': 17.2669
# Euclidean distance between 'to know' and 'smart': 22.8651
# Euclidean distance between 'to hit' and 'to box': 8.4749
# Euclidean distance between 'to beat' and 'to box': 6.7861
# Euclidean distance between 'dog' and 'dog': 0.0000
# Euclidean distance between 'to catch' and 'to catch': 0.0000
# Euclidean distance between 'to cheer' and 'to cheer': 0.0000
# Euclidean distance between 'to sing' and 'to sing': 0.0000
# Euclidean distance between 'female' and 'pregnant': 14.2269
# Euclidean distance between 'female' and 'hair': 20.6948
# Euclidean distance between 'female' and 'to shower': 23.6709
# Euclidean distance between 'to burn' and 'pain': 19.5062
# Euclidean distance between 'to burn' and 'burnt': 21.9429
# Euclidean distance between 'to burn' and 'hot': 19.5937
# Euclidean distance between 'I' and 'I': 0.0000
# Euclidean distance between 'to chew' and 'to chew': 0.0000
# Euclidean distance between 'to fly' and 'bird': 22.0261
# Euclidean distance between 'to fly' and 'airplane': 24.7341
# Euclidean distance between 'to fly' and 'to fly': 0.0000
# Euclidean distance between 'maybe' and 'to think': 20.4480
# Euclidean distance between 'maybe' and 'to choose': 18.2901
# Euclidean distance between 'maybe' and 'to doubt': 22.3093
# Euclidean distance between 'lightning' and 'graffiti': 24.1001
# Euclidean distance between 'lightning' and 'fireworks': 19.4507
# Euclidean distance between 'lightning' and 'bomb': 19.0915
# Euclidean distance between 'smile' and 'to smile': 23.2204
# Euclidean distance between 'smile' and 'to laugh': 24.3208
# Euclidean distance between 'smile' and 'smile': 0.0000
# Euclidean distance between 'clock' and 'clock': 0.0000
# Euclidean distance between 'big' and 'to wonder': 21.4122
# Euclidean distance between 'big' and 'height': 20.9121
# Euclidean distance between 'big' and 'big': 0.0000
# Euclidean distance between 'high' and 'height': 14.9756
# Euclidean distance between 'high' and 'space': 17.9690
# Euclidean distance between 'high' and 'to misjudge': 20.5533
# Euclidean distance between 'happy' and 'to wait': 21.3976
# Euclidean distance between 'happy' and 'satisfied': 15.8211
# Euclidean distance between 'happy' and 'happy': 0.0000
# Euclidean distance between 'fish' and 'fish': 0.0000
# Euclidean distance between 'to smell' and 'to smell': 0.0000
# Euclidean distance between 'wind' and 'wind': 0.0000
# Euclidean distance between 'hot' and 'pain': 14.5105
# Euclidean distance between 'hot' and 'to burn': 19.5937
# Euclidean distance between 'hot' and 'hot': 0.0000
# Euclidean distance between 'bicycle' and 'to cycle': 21.4449
# Euclidean distance between 'airplane' and 'to fly': 24.7341
# Euclidean distance between 'airplane' and 'airplane': 0.0000
# Euclidean distance between 'bird' and 'bird': 0.0000
# Euclidean distance between 'to crawl' and 'to crawl': 0.0000
# Euclidean distance between 'water' and 'to drink': 24.1631
# Euclidean distance between 'water' and 'waterfall': 16.0787
# Euclidean distance between 'water' and 'water': 0.0000
# Euclidean distance between 'fire' and 'fire': 0.0000
# Euclidean distance between 'good' and 'top': 23.2354
# Euclidean distance between 'good' and 'good': 0.0000
# Euclidean distance between 'to hear' and 'to hear': 0.0000
# Euclidean distance between 'far' and 'to point': 19.9365
# Euclidean distance between 'far' and 'distance': 14.2463
# Euclidean distance between 'far' and 'there': 16.4423
# Euclidean distance between 'secret' and 'to whisper': 24.5439
# Euclidean distance between 'secret' and 'quiet': 19.1461
# Euclidean distance between 'secret' and 'to be silent': 25.6677
# Euclidean distance between 'telephone' and 'telephone': 0.0000
# Euclidean distance between 'to blow' and 'to blow': 0.0000
# Euclidean distance between 'to give' and 'to distribute': 7.9041
# Euclidean distance between 'to give' and 'to give': 0.0000
# Euclidean distance between 'cat' and 'cat': 0.0000
# Euclidean distance between 'to laugh' and 'to laugh': 0.0000
# Euclidean distance between 'sweet' and 'tasty': 24.5352
# Euclidean distance between 'sweet' and 'to eat': 23.0623
# Euclidean distance between 'sweet' and 'yummy': 19.0154
# Euclidean distance between 'to sleep' and 'to sleep': 0.0000
# Euclidean distance between 'mountain' and 'mountain': 0.0000
# Euclidean distance between 'sick' and 'dirty': 16.5699
# Euclidean distance between 'sick' and 'to vomit': 19.4080
# Euclidean distance between 'sick' and 'to be disgusted': 23.5848
# Euclidean distance between 'to wave' and 'to greet': 12.6071
# Euclidean distance between 'to wave' and 'hello': 21.9671
# Euclidean distance between 'to wave' and 'goodbye': 24.7101
# Euclidean distance between 'odor' and 'to smell': 22.7119
# Euclidean distance between 'odor' and 'nose': 16.8370
# Euclidean distance between 'odor' and 'odor': 0.0000
# Euclidean distance between 'fly' and 'to fly': 10.3595
# Euclidean distance between 'fly' and 'fireworks': 22.6031
# Euclidean distance between 'fly' and 'to blow': 11.4733
# Euclidean distance between 'sharp' and 'to cut': 23.1515
# Euclidean distance between 'sharp' and 'pain': 17.3633
# Euclidean distance between 'sharp' and 'hot': 18.8988
# Euclidean distance between 'tail' and 'to slurp': 21.4328
# Euclidean distance between 'tail' and 'to throw': 21.7773
# Euclidean distance between 'tail' and 'to fall': 21.7755
# Euclidean distance between 'to fall' and 'to fall': 0.0000
# Euclidean distance between 'squeak' and 'whistle': 19.4015
# Euclidean distance between 'squeak' and 'heartbeat': 20.9447
# Euclidean distance between 'squeak' and 'mouse': 13.3274
# Euclidean distance between 'to hunt' and 'to hit': 7.8755
# Euclidean distance between 'to hunt' and 'to catch': 6.2523
# Euclidean distance between 'to hunt' and 'to grab': 8.6521
# Euclidean distance between 'ball' and 'to throw': 24.3485
# Euclidean distance between 'ball' and 'to fall': 23.9658
# Euclidean distance between 'ball' and 'to shoot': 23.3702
# Euclidean distance between 'snow' and 'circus': 20.9843
# Euclidean distance between 'snow' and 'trunk': 18.9679
# Euclidean distance between 'snow' and 'to fall': 22.9229
# Euclidean distance between 'heavy' and 'to fight': 12.6483
# Euclidean distance between 'heavy' and 'pain': 17.6633
# Euclidean distance between 'heavy' and 'to push open': 14.2736
# Euclidean distance between 'to growl' and 'to growl': 0.0000
# Euclidean distance between 'salt' and 'to cut': 11.1553
# Euclidean distance between 'salt' and 'to eat': 11.9803
# Euclidean distance between 'salt' and 'knife': 22.3970
# Euclidean distance between 'to suck' and 'to slurp': 6.6846
# Euclidean distance between 'to suck' and 'to drink': 8.5631
# Euclidean distance between 'to suck' and 'drink': 20.5910
# Euclidean distance between 'thick' and 'to eat': 12.4757
# Euclidean distance between 'thick' and 'delicious': 21.1108
# Euclidean distance between 'thick' and 'tasty': 12.7051
# Euclidean distance between 'sick' and 'to cough': 23.0968
# Euclidean distance between 'sick' and 'sick': 0.0000
# Euclidean distance between 'to cry' and 'to cry': 0.0000
# Euclidean distance between 'to weep' and 'to cry': 7.9971

# %% [markdown]
# # Similarity survey

# %%
# load in excel similarity_en_survey
df_survey = pd.read_excel(answerfolder + '/similarity_en_survey.xlsx')

# get rid of Timestamp column
df_survey = df_survey.drop(columns='Timestamp')

# for each column, calculate the mean and save it to a df
df_survey_means = pd.DataFrame(df_survey.mean()).reset_index()

# separate the index, the first part is English, the second part is the answer_en
df_survey_means['English'] = df_survey_means['index'].str.split(' - ').str[0]
df_survey_means['answer_en'] = df_survey_means['index'].str.split(' - ').str[1]

# get rid of the index column
df_survey_means = df_survey_means.drop(columns='index')

# rename the column 0 to mean_similarity
df_survey_means = df_survey_means.rename(columns={0: 'mean_similarity'})

# change to lightning into lightning
df_survey_means.loc[df_survey_means['answer_en'] == 'to lightning', 'answer_en'] = 'lightning'
# phone to telephone
df_survey_means.loc[df_survey_means['answer_en'] == 'phone', 'answer_en'] = 'telephone'
# scent to odor
df_survey_means.loc[df_survey_means['answer_en'] == 'scent', 'answer_en'] = 'odor'

# %%
# merge df_survey_means with df on English and answer_en
df_final = pd.merge(df, df_survey_means, on=['English', 'answer_en'], how='left')

# get rid of English 'to beat'
df_final = df_final[df_final['English'] != 'to beat']
# and to weep
df_final = df_final[df_final['English'] != 'to weep']

# %%
# show me the rows where mean_similarity is NaN
df_final[df_final['mean_similarity'].isnull()]

# mean_similarity of row where English is sharp and answer_en is pain is 4.0 (don't know why it's NaN)
df_final.loc[(df_final['English'] == 'sharp') & (df_final['answer_en'] == 'pain'), 'mean_similarity'] = 4.0

# %%
# correlation between cosine_similarity and mean_similarity
print(df_final['cosine_similarity'].corr(df_final['mean_similarity']))


# and euclidean_similarity and mean_similarity
print(df_final['euclidean_similarity'].corr(df_final['mean_similarity']))

# So it seems that the euclidean_similarity correlates better with the survey results than the cosine_similarity
# Out:
# 0.5936420578375975
# -0.7125549637795267

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# Compute the correlation coefficient
corr_coef, _ = pearsonr(df_final['euclidean_similarity'], df_final['mean_similarity'])

# Create scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(x=df_final['euclidean_similarity'], y=df_final['mean_similarity'], data=df, ci=None, scatter_kws={'s': 50, 'alpha': 0.7})

# Customize plot
plt.title(f'Scatter Plot of euclidean distance vs mean similarity\nCorrelation Coefficient: {corr_coef:.2f}', fontsize=16)
plt.xlabel('euclidean_distance', fontsize=14)
plt.ylabel('mean_similarity', fontsize=14)

# Show plot
plt.show()

# %%
df_final
# Out:
#         word    answer  exp     English   answer_en  cosine_similarity  \
# 0      bloem     feest    1      flower       party           0.161149
# 1     dansen   juichen    1    to dance    to cheer           0.684747
# 2     bitter    lekker    1      bitter       tasty           0.082420
# 3    vechten  schieten    1    to fight    to shoot           0.947234
# 4     ademen    ademen    1  to breathe  to breathe           1.000000
# ..       ...       ...  ...         ...         ...                ...
# 165      dik  heerlijk    2       thick   delicious           0.182059
# 166      dik    lekker    2       thick       tasty           0.807506
# 167     ziek   hoesten    2        sick    to cough           0.131773
# 168     ziek      ziek    2        sick        sick           1.000000
# 169   huilen    huilen    2      to cry      to cry           1.000000
#
#      euclidean_similarity  mean_similarity
# 0               23.574501              2.1
# 1               12.545033              3.6
# 2               26.284916              3.0
# 3                6.124245              5.1
# 4                0.000000             10.0
# ..                    ...              ...
# 165             21.110804              2.0
# 166             12.705090              1.5
# 167             23.096788              6.2
# 168              0.000000             10.0
# 169              0.000000             10.0
#
# [169 rows x 8 columns]

# %%
# save as csv
df_final.to_csv(answerfolder + '/similarity_comparison.csv', index=False)

# %% [markdown]
# # Density
#
# Now we want to know how is concept's environemnt dense. We will use BERT embeddings for this, and then define density as a mean of cosine similarities between all pairs of embeddings.
#
# But we cannot run it on the whole model corpora, so we will sample 10000 keys

# %% [markdown]
# ## English

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
model = BertModel.from_pretrained('bert-large-cased')
# Out:
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.

# %%
# load in similarity_comparison.csv
df = pd.read_csv(answerfolder + '/similarity_comparison.csv')

# from col English, make list that we want to compute density for
words = list(df['English'])

# %%
def get_embedding(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    
    # Get the outputs from the model
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract the embedding from the [CLS] token (index 0)
    cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
    
    return cls_embedding

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# prepare empty dictionary
embeddings = {}

# Convert tokenizer vocab keys to a list
vocab_list = list(tokenizer.vocab.keys())

# Sample a subset of words from the BERT vocabulary
# For example, let's sample 1000 words from the vocabulary
vocab_sample = np.random.choice(vocab_list, size=10000, replace=False)

# Get embeddings for the sampled words
word_embeddings = [get_embedding(word) for word in vocab_sample]

for word in words:
    print(f"Embedding for {word}")

    # Get the embedding for the concept (e.g., "sustainability")
    concept_embedding = get_embedding(word)

    # Calculate cosine similarities between the concept and the sampled words
    similarities = [cosine_similarity([concept_embedding], [embedding])[0][0] for embedding in word_embeddings]

    # Calculate average distance (1 - similarity)
    avg_distance = np.mean([1 - sim for sim in similarities])

    # Calculate density (inverse of average distance)
    density = 1 / avg_distance

    # Save the density to the dictionary
    embeddings[word] = density
# Out:
# Embedding for flower
# Embedding for to dance
# Embedding for bitter
# Embedding for to fight
# Embedding for to breathe
# Embedding for to bite
# Embedding for buzz
# Embedding for to whisper
# Embedding for disgusted
# Embedding for slow
# Embedding for car
# Embedding for to eat
# Embedding for egg
# Embedding for to swim
# Embedding for fast
# Embedding for rain
# Embedding for angry
# Embedding for noisy
# Embedding for loud
# Embedding for fast
# Embedding for elephant
# Embedding for sad
# Embedding for cold
# Embedding for to stand
# Embedding for silent
# Embedding for to walk
# Embedding for scared
# Embedding for to throw
# Embedding for to hurry
# Embedding for crazy
# Embedding for to run
# Embedding for to lick
# Embedding for small
# Embedding for thunder
# Embedding for male
# Embedding for to jump
# Embedding for slow
# Embedding for to cut
# Embedding for comfortable
# Embedding for child
# Embedding for horn
# Embedding for to vomit
# Embedding for dead
# Embedding for to drink
# Embedding for strong
# Embedding for old
# Embedding for to cook
# Embedding for snake
# Embedding for snake
# Embedding for sour
# Embedding for not
# Embedding for to know
# Embedding for to hit
# Embedding for dog
# Embedding for to catch
# Embedding for to cheer
# Embedding for to sing
# Embedding for female
# Embedding for female
# Embedding for female
# Embedding for to burn
# Embedding for to burn
# Embedding for to burn
# Embedding for I
# Embedding for to chew
# Embedding for to fly
# Embedding for to fly
# Embedding for to fly
# Embedding for maybe
# Embedding for maybe
# Embedding for maybe
# Embedding for lightning
# Embedding for lightning
# Embedding for lightning
# Embedding for smile
# Embedding for smile
# Embedding for smile
# Embedding for clock
# Embedding for big
# Embedding for big
# Embedding for big
# Embedding for high
# Embedding for high
# Embedding for high
# Embedding for happy
# Embedding for happy
# Embedding for happy
# Embedding for fish
# Embedding for to smell
# Embedding for wind
# Embedding for hot
# Embedding for hot
# Embedding for hot
# Embedding for bicycle
# Embedding for airplane
# Embedding for airplane
# Embedding for bird
# Embedding for to crawl
# Embedding for water
# Embedding for water
# Embedding for water
# Embedding for fire
# Embedding for good
# Embedding for good
# Embedding for to hear
# Embedding for far
# Embedding for far
# Embedding for far
# Embedding for secret
# Embedding for secret
# Embedding for secret
# Embedding for telephone
# Embedding for to blow
# Embedding for to give
# Embedding for to give
# Embedding for cat
# Embedding for to laugh
# Embedding for sweet
# Embedding for sweet
# Embedding for sweet
# Embedding for to sleep
# Embedding for mountain
# Embedding for sick
# Embedding for sick
# Embedding for sick
# Embedding for to wave
# Embedding for to wave
# Embedding for to wave
# Embedding for odor
# Embedding for odor
# Embedding for odor
# Embedding for fly
# Embedding for fly
# Embedding for fly
# Embedding for sharp
# Embedding for sharp
# Embedding for sharp
# Embedding for tail
# Embedding for tail
# Embedding for tail
# Embedding for to fall
# Embedding for squeak
# Embedding for squeak
# Embedding for squeak
# Embedding for to hunt
# Embedding for to hunt
# Embedding for to hunt
# Embedding for ball
# Embedding for ball
# Embedding for ball
# Embedding for snow
# Embedding for snow
# Embedding for snow
# Embedding for heavy
# Embedding for heavy
# Embedding for heavy
# Embedding for to growl
# Embedding for salt
# Embedding for salt
# Embedding for salt
# Embedding for to suck
# Embedding for to suck
# Embedding for to suck
# Embedding for thick
# Embedding for thick
# Embedding for thick
# Embedding for sick
# Embedding for sick
# Embedding for to cry

# %% [markdown]
# ## Visualize

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Add the concept embedding to the list of embeddings
all_embeddings = word_embeddings + [concept_embedding]

# Apply PCA to reduce dimensionality to 2D
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(all_embeddings)

# Plot the reduced embeddings
plt.figure(figsize=(10, 8))
plt.scatter(reduced_embeddings[:-1, 0], reduced_embeddings[:-1, 1], color='blue', label='Vocabulary Samples')
plt.scatter(reduced_embeddings[-1, 0], reduced_embeddings[-1, 1], color='red', label='Concept: Sustainability', s=100)

# Add labels and a legend
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('2D Visualization of Concept Embedding and Sampled Words')
plt.legend()
plt.show()

# %%
## add it to df
df['density'] = df['English'].map(embeddings)

## save it to csv
df.to_csv(answerfolder + '/concept_similarity_and_density.csv', index=False)

# %% [markdown]
# ## The same but with Dutch model

# %%
from transformers import BertTokenizer, BertModel
import torch

# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('wietsedv/bert-base-dutch-cased')
model = BertModel.from_pretrained('wietsedv/bert-base-dutch-cased')
# Out:
# c:\Users\kadava\AppData\Local\anaconda3\envs\BERT\Lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\kadava\.cache\huggingface\hub\models--wietsedv--bert-base-dutch-cased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Some weights of BertModel were not initialized from the model checkpoint at wietsedv/bert-base-dutch-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# load in similarity_comparison.csv
df = pd.read_csv(answerfolder + '/similarity_comparison.csv')

# from col English, make list that we want to compute density for
words = list(df['word'])

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# prepare empty dictionary
embeddings = {}

# Convert tokenizer vocab keys to a list
vocab_list = list(tokenizer.vocab.keys())

# Sample a subset of words from the BERT vocabulary
# For example, let's sample 1000 words from the vocabulary
vocab_sample = np.random.choice(vocab_list, size=10000, replace=False)

# Get embeddings for the sampled words
word_embeddings = [get_embedding(word) for word in vocab_sample]

for word in words:
    print(f"Embedding for {word}")

    # Get the embedding for the concept (e.g., "sustainability")
    concept_embedding = get_embedding(word)

    # Calculate cosine similarities between the concept and the sampled words
    similarities = [cosine_similarity([concept_embedding], [embedding])[0][0] for embedding in word_embeddings]

    # Calculate average distance (1 - similarity)
    avg_distance = np.mean([1 - sim for sim in similarities])

    # Calculate density (inverse of average distance)
    density = 1 / avg_distance

    # Save the density to the dictionary
    embeddings[word] = density
# Out:
# Embedding for bloem
# Embedding for dansen
# Embedding for bitter
# Embedding for vechten
# Embedding for ademen
# Embedding for bijten
# Embedding for zoemen
# Embedding for fluisteren
# Embedding for walgen
# Embedding for langzaam
# Embedding for auto
# Embedding for eten
# Embedding for ei
# Embedding for zwemmen
# Embedding for snel
# Embedding for regen
# Embedding for boos
# Embedding for luidruchtig
# Embedding for luidruchtig
# Embedding for snel
# Embedding for olifant
# Embedding for verdrietig
# Embedding for koud
# Embedding for staan
# Embedding for stil
# Embedding for lopen
# Embedding for bang
# Embedding for gooien
# Embedding for haasten
# Embedding for gek
# Embedding for rennen
# Embedding for likken
# Embedding for klein
# Embedding for onweer
# Embedding for man
# Embedding for springen
# Embedding for langzaam
# Embedding for snijden
# Embedding for comfortabel
# Embedding for kind
# Embedding for hoorn
# Embedding for kotsen
# Embedding for dood
# Embedding for drinken
# Embedding for sterk
# Embedding for oud
# Embedding for koken
# Embedding for slang
# Embedding for slang
# Embedding for zuur
# Embedding for niet
# Embedding for weten
# Embedding for slaan
# Embedding for hond
# Embedding for vangen
# Embedding for juichen
# Embedding for zingen
# Embedding for vrouw
# Embedding for vrouw
# Embedding for vrouw
# Embedding for verbranden
# Embedding for verbranden
# Embedding for verbranden
# Embedding for ik
# Embedding for kauwen
# Embedding for vliegen
# Embedding for vliegen
# Embedding for vliegen
# Embedding for misschien
# Embedding for misschien
# Embedding for misschien
# Embedding for bliksem
# Embedding for bliksem
# Embedding for bliksem
# Embedding for glimlach
# Embedding for glimlach
# Embedding for glimlach
# Embedding for klok
# Embedding for groot
# Embedding for groot
# Embedding for groot
# Embedding for hoog
# Embedding for hoog
# Embedding for hoog
# Embedding for blij
# Embedding for blij
# Embedding for blij
# Embedding for vis
# Embedding for ruiken
# Embedding for wind
# Embedding for heet
# Embedding for heet
# Embedding for heet
# Embedding for fiets
# Embedding for vliegtuig
# Embedding for vliegtuig
# Embedding for vogel
# Embedding for kruipen
# Embedding for water
# Embedding for water
# Embedding for water
# Embedding for vuur
# Embedding for goed
# Embedding for goed
# Embedding for horen
# Embedding for ver
# Embedding for ver
# Embedding for ver
# Embedding for geheim
# Embedding for geheim
# Embedding for geheim
# Embedding for telefoon
# Embedding for blazen
# Embedding for geven
# Embedding for geven
# Embedding for kat
# Embedding for lachen
# Embedding for zoet
# Embedding for zoet
# Embedding for zoet
# Embedding for slapen
# Embedding for berg
# Embedding for ziek
# Embedding for ziek
# Embedding for ziek
# Embedding for zwaaien
# Embedding for zwaaien
# Embedding for zwaaien
# Embedding for geur
# Embedding for geur
# Embedding for geur
# Embedding for vlieg
# Embedding for vlieg
# Embedding for vlieg
# Embedding for scherp
# Embedding for scherp
# Embedding for scherp
# Embedding for staart
# Embedding for staart
# Embedding for staart
# Embedding for vallen
# Embedding for piepen
# Embedding for piepen
# Embedding for piepen
# Embedding for jagen
# Embedding for jagen
# Embedding for jagen
# Embedding for bal
# Embedding for bal
# Embedding for bal
# Embedding for sneeuw
# Embedding for sneeuw
# Embedding for sneeuw
# Embedding for zwaar
# Embedding for zwaar
# Embedding for zwaar
# Embedding for grommen
# Embedding for zout
# Embedding for zout
# Embedding for zout
# Embedding for zuigen
# Embedding for zuigen
# Embedding for zuigen
# Embedding for dik
# Embedding for dik
# Embedding for dik
# Embedding for ziek
# Embedding for ziek
# Embedding for huilen

# %%
# load in concept_similarity_and_density.csv
df = pd.read_csv(answerfolder + '/concept_similarity_and_density.csv')

# add density_nl to df
df['density_nl'] = df['word'].map(embeddings)

# write to csv
df.to_csv(answerfolder + '/concept_similarity_and_density.csv', index=False)
